# %% [markdown]
# <a href="https://colab.research.google.com/github/azithteja91/amphi_rl_dpgraph/blob/main/demo_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/azithteja91/amphi_rl_dpgraph.git
# %cd amphi_rl_dpgraph
# Out:
# Cloning into 'amphi_rl_dpgraph'...
# remote: Enumerating objects: 323, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 323 (delta 131), reused 134 (delta 93), pack-reused 108 (from 1)
# Receiving objects: 100% (323/323), 499.60 KiB | 2.09 MiB/s, done.
# Resolving deltas: 100% (146/146), done.
# /content/amphi_rl_dpgraph

# %%
# !python3 -m pip install -U pip setuptools wheel
# !python3 -m pip install -e .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...
# Obtaining file:///content/amphi_rl_dpgraph
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...

# %%
# !python3 -m amphi_rl_dpgraph.run_demo
# Out:
# modules.json: 100% 349/349 [00:00<00:00, 1.20MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 426kB/s]
# README.md: 10.5kB [00:00, 22.3MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 246kB/s]
# config.json: 100% 612/612 [00:00<00:00, 2.07MB/s]
# ...
# model.safetensors: 100% 90.9M/90.9M [00:01<00:00, 80.9MB/s]
# Loading weights: 100% 103/103 [00:00<00:00, 1243.96it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.49MB/s]
# vocab.txt: 232kB [00:00, 9.66MB/s]
# tokenizer.json: 466kB [00:00, 27.6MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 513kB/s]
# ...

# %%
# !zip -r results.zip results
# Out:
#   adding: results/ (stored 0%)
#   adding: results/audit_checkpoints_adaptive.jsonl (deflated 64%)
#   adding: results/audit_log.jsonl (deflated 98%)
#   adding: results/policy_metrics.csv (deflated 53%)
#   adding: results/dcpg_adaptive.sqlite (deflated 89%)
#   adding: results/sample_dag.dot (deflated 31%)
#   adding: results/EXPERIMENT_REPORT.md (deflated 62%)
#   adding: results/dcpg_snapshot.json (deflated 94%)
#   adding: results/privacy_utility_curve.png (deflated 16%)
#   adding: results/sample_dag.png (deflated 20%)
#   adding: results/ppo_model.pt (deflated 9%)
#   adding: results/dcpg_crdt_demo.json (deflated 83%)
#   adding: results/rl_reward_stats.json (deflated 50%)
#   adding: results/sample_run/ (stored 0%)
#   adding: results/sample_run/policy_metrics.csv (deflated 55%)
#   adding: results/sample_run/sample_dag.dot (deflated 31%)
#   adding: results/sample_run/EXPERIMENT_REPORT.md (deflated 62%)
#   adding: results/sample_run/dcpg_snapshot.json (deflated 91%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r results /content/drive/MyDrive/amphi_rl_dpgraph_results
# Out:
# Mounted at /content/drive
